# %% [markdown]
# <a href="https://colab.research.google.com/github/NNhanptnk/MaSSP-2019/blob/master/Keras36(Vuhuutiep)_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras import optimizers

import matplotlib ## Thư viện matplotlib
import matplotlib.pyplot as plt ##Lấy func plot của thư viện matplotlib
np.random.seed(2) ## Random 

# 1. create pseudo data y = 2*x0 + 3*x1 + 4
X = np.random.rand(1000, 1)
y = 4 + 3 * X + .2*np.random.randn(1000, 1) # noise added

# 2. Build model 
model = Sequential([Dense(1, input_shape = (1,), activation='linear')])

# 3. gradient descent optimizer and loss function 
sgd = optimizers.SGD(lr=0.1)
model.compile(loss='mse', optimizer=sgd)

# 4. Train the model 
model.fit(X, y, epochs=100, batch_size=1)


# Display result
w=model.get_weights()
w_0 = w[0][0]
w_1 = w[1][0]
x0 = np.linspace(0, 1, 2, endpoint=True) ## Điểm 
y0 = w_0 + w_1*x0 ## Đường thẳng

print(w)

# Draw the fitting line 
plt.plot(X.T, y.T, 'b.')     # data 
plt.plot(x0, y0, 'y', linewidth = 2)   # the fitting line
plt.axis([0, 1, 0, 10]) ## Vẽ trục 
plt.show()
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 1s 815us/step - loss: 0.1163
# Epoch 2/100
# 1000/1000 [==============================] - 1s 724us/step - loss: 0.0444
# Epoch 3/100
# 1000/1000 [==============================] - 1s 716us/step - loss: 0.0437
# Epoch 4/100
# 1000/1000 [==============================] - 1s 720us/step - loss: 0.0431
# Epoch 5/100
# 1000/1000 [==============================] - 1s 733us/step - loss: 0.0438
# Epoch 6/100
# 1000/1000 [==============================] - 1s 710us/step - loss: 0.0435
# Epoch 7/100
# 1000/1000 [==============================] - 1s 725us/step - loss: 0.0438
# Epoch 8/100
# 1000/1000 [==============================] - 1s 728us/step - loss: 0.0434
# Epoch 9/100
# 1000/1000 [==============================] - 1s 733us/step - loss: 0.0443
# Epoch 10/100
# 1000/1000 [==============================] - 1s 736us/step - loss: 0.0427
# Epoch 11/100
# 1000/1000 [==============================] - 1s 745us/step - loss: 0.0436
# ...
